# %% [markdown]
# # Assignment 2: Gesture Recognition Using Convolutional Neural Networks
# ## Tensorflow Version : 2.18.0
# ## Caolán Maguire G00385433

# %%
#!/usr/bin/env python
# coding: utf-8

# # Gesture UI Recognition
#
# Goal: Create a model that identifies hand gestures from images
#
# This code closely follows the structure and libraries used in the Pokemon classification example

# I have this included to suppress some tensorflow warnings and errors

import matplotlib.pyplot as plt
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

os.makedirs('./cachepath', exist_ok=True)

# %%
# # from google.colab import drive
# # drive.mount('/content/drive')

# # import os
# # import shutil

# # folder_path = '/content/drive/MyDrive'
# shutil.rmtree(folder_path)  # Caution: permanently deletes!

# %%
# # pip install tensorflow

from google.colab import drive
drive.mount('/content/drive')

import zipfile
import os

# Adjust this path if you uploaded to a subfolder
zip_path = "/content/drive/MyDrive/hagridset.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/hagridset")

# Confirm it worked
os.listdir("/content/hagridset")


# # !rm -rf /content/hagridset
# Out:
# Mounted at /content/drive
# ['hagridset']

# %%
import gc
import tensorflow as tf
gc.collect()
tf.keras.backend.clear_session()
import numpy as np

import pandas as pd

# %%
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.18.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
STUDENT_ID = 385433

# %%
# ## Setting Up the Dataset
#
# Starting with a smaller image size (128x128) for faster training, just like the Pokemon example

IMG_SIZE = (128, 128)
batch_size = 32

# For HAGRID dataset:
train_dir = "hagridset/hagridset"

# %%
# Training dataset (70%)
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=IMG_SIZE,
    validation_split=0.3,  # 30% will be split between validation and test
    subset='training',
    label_mode='categorical',
    seed=STUDENT_ID,
    batch_size=batch_size
)
# Out:
# Found 125912 files belonging to 18 classes.
# Using 88139 files for training.

# %%
# Validation dataset (10% of total)
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=IMG_SIZE,
    validation_split=0.3,
    subset='validation',
    label_mode='categorical',
    seed=STUDENT_ID,
    batch_size=batch_size
)

# In this case we're using the validation set as both validation and test
# We'll split it further as was done in the Pokemon example
val_batches = tf.data.experimental.cardinality(validation_dataset) // 3
test_dataset = validation_dataset.skip(val_batches)
validation_dataset = validation_dataset.take(val_batches)
# Out:
# Found 125912 files belonging to 18 classes.
# Using 37773 files for validation.

# %%
num_classes = len(train_dataset.class_names)

# %%
class_names = train_dataset.class_names
print(f"Found {num_classes} classes: {class_names}")
# Out:
# Found 18 classes: ['call', 'dislike', 'fist', 'four', 'like', 'mute', 'ok', 'one', 'palm', 'peace', 'peace_inverted', 'rock', 'stop', 'stop_inverted', 'three', 'three2', 'two_up', 'two_up_inverted']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.cache('./cachepath/train_cache').prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.cache('./cachepath/val_cache').prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.cache('./cachepath/test_cache').prefetch(buffer_size=AUTOTUNE)

# %%
# Basic dataset info
print(train_dataset)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 18), dtype=tf.float32, name=None))>

# %%
from tensorflow.keras import layers

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        label_index = np.argmax(labels[i])
        plt.title(class_names[label_index])
        plt.axis("off")
plt.show()

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)))
model.add(layers.Rescaling(1./255))
model.add(layers.Conv2D(16, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(layers.Conv2D(32, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(num_classes, activation='softmax'))

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     4,194,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 18)             │         2,322 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,201,842 (16.03 MB)
#  Trainable params: 4,201,842 (16.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early stopping callback to prevent overfitting
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %%
# Train the model
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 76s 26ms/step - accuracy: 0.1813 - loss: 2.5744 - val_accuracy: 0.3965 - val_loss: 1.8998
# Epoch 2/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.4299 - loss: 1.7881 - val_accuracy: 0.4571 - val_loss: 1.7198
# Epoch 3/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.5484 - loss: 1.4027 - val_accuracy: 0.4711 - val_loss: 1.7504
# Epoch 4/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.6568 - loss: 1.0591 - val_accuracy: 0.4517 - val_loss: 2.0407
# Epoch 5/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.7558 - loss: 0.7632 - val_accuracy: 0.4155 - val_loss: 2.4616
# Epoch 6/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.8169 - loss: 0.5587 - val_accuracy: 0.4109 - val_loss: 2.9686
# Epoch 7/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.8667 - loss: 0.4038 - val_accuracy: 0.4148 - val_loss: 3.3327

# %% [markdown]
# # Model 2: CNN with Data Augmentation
#
# ## Adding data augmentation to improve generalization, following the Pokemon example

# %%
data_augmentation_layers = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
])

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)))
model.add(data_augmentation_layers)
model.add(layers.Rescaling(1./255))
model.add(layers.Conv2D(16, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(layers.Conv2D(32, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(num_classes, activation='softmax'))

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history_aug = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 9ms/step - accuracy: 0.0876 - loss: 2.8553 - val_accuracy: 0.2053 - val_loss: 2.4624
# Epoch 2/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.2031 - loss: 2.4858 - val_accuracy: 0.2855 - val_loss: 2.2074
# Epoch 3/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.2594 - loss: 2.2882 - val_accuracy: 0.3303 - val_loss: 2.0678
# Epoch 4/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.3053 - loss: 2.1440 - val_accuracy: 0.3719 - val_loss: 1.9337
# Epoch 5/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.3475 - loss: 2.0178 - val_accuracy: 0.4115 - val_loss: 1.8196
# Epoch 6/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.3823 - loss: 1.9077 - val_accuracy: 0.4302 - val_loss: 1.7540
# Epoch 7/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.4122 - loss: 1.8192 - val_accuracy: 0.4536 - val_loss: 1.6873
# Epoch 8/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.4350 - loss: 1.7532 - val_accuracy: 0.4788 - val_loss: 1.5987
# Epoch 9/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.4522 - loss: 1.7007 - val_accuracy: 0.4871 - val_loss: 1.5743
# Epoch 10/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.4636 - loss: 1.6592 - val_accuracy: 0.5007 - val_loss: 1.5330
# Epoch 11/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.4753 - loss: 1.6229 - val_accuracy: 0.5094 - val_loss: 1.5151
# Epoch 12/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.4835 - loss: 1.6029 - val_accuracy: 0.5002 - val_loss: 1.5381
# Epoch 13/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.4923 - loss: 1.5743 - val_accuracy: 0.5226 - val_loss: 1.4605
# Epoch 14/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5010 - loss: 1.5564 - val_accuracy: 0.5294 - val_loss: 1.4407
# Epoch 15/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5041 - loss: 1.5342 - val_accuracy: 0.5260 - val_loss: 1.4587
# Epoch 16/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5090 - loss: 1.5131 - val_accuracy: 0.5456 - val_loss: 1.4110
# Epoch 17/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5190 - loss: 1.4930 - val_accuracy: 0.5303 - val_loss: 1.4323
# Epoch 18/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5238 - loss: 1.4800 - val_accuracy: 0.5481 - val_loss: 1.4020
# Epoch 19/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5359 - loss: 1.4427 - val_accuracy: 0.5600 - val_loss: 1.3689
# Epoch 20/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5416 - loss: 1.4257 - val_accuracy: 0.5576 - val_loss: 1.3814
# Epoch 21/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5512 - loss: 1.3953 - val_accuracy: 0.5744 - val_loss: 1.3347
# Epoch 22/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5559 - loss: 1.3818 - val_accuracy: 0.5760 - val_loss: 1.3132
# Epoch 23/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5624 - loss: 1.3613 - val_accuracy: 0.5820 - val_loss: 1.3039
# Epoch 24/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5687 - loss: 1.3465 - val_accuracy: 0.5829 - val_loss: 1.2831
# Epoch 25/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5719 - loss: 1.3292 - val_accuracy: 0.5866 - val_loss: 1.2928
# Epoch 26/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5778 - loss: 1.3187 - val_accuracy: 0.5785 - val_loss: 1.3284
# Epoch 27/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5825 - loss: 1.3034 - val_accuracy: 0.6003 - val_loss: 1.2515
# Epoch 28/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5849 - loss: 1.2882 - val_accuracy: 0.6019 - val_loss: 1.2528
# Epoch 29/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5916 - loss: 1.2688 - val_accuracy: 0.6034 - val_loss: 1.2551
# Epoch 30/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.5972 - loss: 1.2605 - val_accuracy: 0.6077 - val_loss: 1.2106
# Epoch 31/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 9ms/step - accuracy: 0.5975 - loss: 1.2562 - val_accuracy: 0.6029 - val_loss: 1.2410
# Epoch 32/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 9ms/step - accuracy: 0.6031 - loss: 1.2369 - val_accuracy: 0.6058 - val_loss: 1.2325
# Epoch 33/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.6107 - loss: 1.2175 - val_accuracy: 0.6127 - val_loss: 1.2063
# Epoch 34/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 9ms/step - accuracy: 0.6142 - loss: 1.2023 - val_accuracy: 0.6189 - val_loss: 1.1875
# Epoch 35/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 9ms/step - accuracy: 0.6158 - loss: 1.1943 - val_accuracy: 0.6224 - val_loss: 1.1820
# Epoch 36/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 9ms/step - accuracy: 0.6228 - loss: 1.1762 - val_accuracy: 0.6242 - val_loss: 1.1694
# Epoch 37/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 9ms/step - accuracy: 0.6225 - loss: 1.1685 - val_accuracy: 0.6281 - val_loss: 1.1641
# Epoch 38/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 9ms/step - accuracy: 0.6303 - loss: 1.1592 - val_accuracy: 0.6299 - val_loss: 1.1696
# Epoch 39/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.6255 - loss: 1.1586 - val_accuracy: 0.6353 - val_loss: 1.1418
# Epoch 40/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.6352 - loss: 1.1406 - val_accuracy: 0.6282 - val_loss: 1.1508
# Epoch 41/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.6379 - loss: 1.1325 - val_accuracy: 0.6348 - val_loss: 1.1482
# Epoch 42/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.6386 - loss: 1.1322 - val_accuracy: 0.6391 - val_loss: 1.1265
# Epoch 43/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.6380 - loss: 1.1248 - val_accuracy: 0.6388 - val_loss: 1.1286
# Epoch 44/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 9ms/step - accuracy: 0.6442 - loss: 1.1123 - val_accuracy: 0.6418 - val_loss: 1.1241
# Epoch 45/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.6461 - loss: 1.1074 - val_accuracy: 0.6462 - val_loss: 1.1012
# Epoch 46/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - accuracy: 0.6489 - loss: 1.0924 - val_accuracy: 0.6473 - val_loss: 1.1091
# Epoch 47/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 9ms/step - accuracy: 0.6510 - loss: 1.0902 - val_accuracy: 0.6522 - val_loss: 1.0895
# Epoch 48/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.6510 - loss: 1.0847 - val_accuracy: 0.6450 - val_loss: 1.1102
# Epoch 49/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.6562 - loss: 1.0732 - val_accuracy: 0.6446 - val_loss: 1.1119
# Epoch 50/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.6581 - loss: 1.0654 - val_accuracy: 0.6481 - val_loss: 1.0940
# Epoch 51/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.6615 - loss: 1.0557 - val_accuracy: 0.6384 - val_loss: 1.1324
# Epoch 52/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.6606 - loss: 1.0520 - val_accuracy: 0.6521 - val_loss: 1.0937

# %% [markdown]
# # Model 3: CNN with Data Augmentation and Dropout
#
# ## Adding dropout to further combat overfitting, just like in the Pokemon example

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)))
model.add(data_augmentation_layers)
model.add(layers.Rescaling(1./255))
model.add(layers.Conv2D(16, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(32, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(layers.Flatten())
model.add(layers.Dropout(0.2))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(num_classes, activation='softmax'))

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)


callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

history_dropout = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 30s 10ms/step - accuracy: 0.0984 - loss: 2.8289 - val_accuracy: 0.2498 - val_loss: 2.3934
# Epoch 2/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.2365 - loss: 2.3970 - val_accuracy: 0.3318 - val_loss: 2.0861
# Epoch 3/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.2961 - loss: 2.1922 - val_accuracy: 0.3729 - val_loss: 1.9748
# Epoch 4/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.3346 - loss: 2.0710 - val_accuracy: 0.3887 - val_loss: 1.9377
# Epoch 5/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.3601 - loss: 1.9868 - val_accuracy: 0.4060 - val_loss: 1.8735
# Epoch 6/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.3770 - loss: 1.9362 - val_accuracy: 0.4427 - val_loss: 1.7508
# Epoch 7/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4018 - loss: 1.8685 - val_accuracy: 0.4559 - val_loss: 1.7324
# Epoch 8/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4162 - loss: 1.8237 - val_accuracy: 0.4672 - val_loss: 1.7203
# Epoch 9/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4287 - loss: 1.7824 - val_accuracy: 0.4879 - val_loss: 1.6435
# Epoch 10/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4435 - loss: 1.7382 - val_accuracy: 0.4917 - val_loss: 1.6270
# Epoch 11/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4542 - loss: 1.7054 - val_accuracy: 0.5216 - val_loss: 1.5390
# Epoch 12/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4645 - loss: 1.6748 - val_accuracy: 0.4923 - val_loss: 1.6226
# Epoch 13/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4705 - loss: 1.6503 - val_accuracy: 0.4924 - val_loss: 1.6446
# Epoch 14/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4779 - loss: 1.6331 - val_accuracy: 0.5313 - val_loss: 1.4874
# Epoch 15/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4833 - loss: 1.6180 - val_accuracy: 0.5319 - val_loss: 1.5146
# Epoch 16/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4906 - loss: 1.5870 - val_accuracy: 0.5302 - val_loss: 1.5270
# Epoch 17/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.4981 - loss: 1.5735 - val_accuracy: 0.5299 - val_loss: 1.4971
# Epoch 18/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5014 - loss: 1.5558 - val_accuracy: 0.5414 - val_loss: 1.4704
# Epoch 19/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5081 - loss: 1.5355 - val_accuracy: 0.5561 - val_loss: 1.4327
# Epoch 20/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5170 - loss: 1.5158 - val_accuracy: 0.5602 - val_loss: 1.4105
# Epoch 21/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5217 - loss: 1.5042 - val_accuracy: 0.5565 - val_loss: 1.4391
# Epoch 22/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5279 - loss: 1.4803 - val_accuracy: 0.5491 - val_loss: 1.4484
# Epoch 23/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5282 - loss: 1.4754 - val_accuracy: 0.5491 - val_loss: 1.4360
# Epoch 24/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5334 - loss: 1.4503 - val_accuracy: 0.5526 - val_loss: 1.4208
# Epoch 25/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5360 - loss: 1.4413 - val_accuracy: 0.5690 - val_loss: 1.3768
# Epoch 26/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5433 - loss: 1.4282 - val_accuracy: 0.5565 - val_loss: 1.4081
# Epoch 27/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5425 - loss: 1.4267 - val_accuracy: 0.5678 - val_loss: 1.3601
# Epoch 28/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5465 - loss: 1.4099 - val_accuracy: 0.5668 - val_loss: 1.3905
# Epoch 29/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5523 - loss: 1.3972 - val_accuracy: 0.5645 - val_loss: 1.3911
# Epoch 30/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5560 - loss: 1.3890 - val_accuracy: 0.5764 - val_loss: 1.3534
# Epoch 31/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5572 - loss: 1.3780 - val_accuracy: 0.5691 - val_loss: 1.3673
# Epoch 32/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5568 - loss: 1.3784 - val_accuracy: 0.5716 - val_loss: 1.3793
# Epoch 33/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5598 - loss: 1.3643 - val_accuracy: 0.5860 - val_loss: 1.3267
# Epoch 34/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5652 - loss: 1.3544 - val_accuracy: 0.5641 - val_loss: 1.3913
# Epoch 35/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5694 - loss: 1.3426 - val_accuracy: 0.5922 - val_loss: 1.3038
# Epoch 36/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5734 - loss: 1.3375 - val_accuracy: 0.5934 - val_loss: 1.3054
# Epoch 37/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5701 - loss: 1.3397 - val_accuracy: 0.5874 - val_loss: 1.3181
# Epoch 38/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5804 - loss: 1.3106 - val_accuracy: 0.5958 - val_loss: 1.2932
# Epoch 39/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5809 - loss: 1.3130 - val_accuracy: 0.5793 - val_loss: 1.3393
# Epoch 40/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5791 - loss: 1.3114 - val_accuracy: 0.5902 - val_loss: 1.3105
# Epoch 41/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5864 - loss: 1.2936 - val_accuracy: 0.6049 - val_loss: 1.2545
# Epoch 42/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5847 - loss: 1.2902 - val_accuracy: 0.6035 - val_loss: 1.2283
# Epoch 43/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5873 - loss: 1.2836 - val_accuracy: 0.6018 - val_loss: 1.2575
# Epoch 44/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5877 - loss: 1.2747 - val_accuracy: 0.5975 - val_loss: 1.2618
# Epoch 45/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5917 - loss: 1.2668 - val_accuracy: 0.5997 - val_loss: 1.2685
# Epoch 46/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5939 - loss: 1.2580 - val_accuracy: 0.5841 - val_loss: 1.3247
# Epoch 47/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - accuracy: 0.5939 - loss: 1.2629 - val_accuracy: 0.6072 - val_loss: 1.2398

# %% [markdown]
# # Model 4: Grayscale Images
#
# ## Let's create a dataset with grayscale images for comparison
# ## This is an addition to the Pokemon example which only used RGB

# %%
# Load grayscale images
train_dataset_gray = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=IMG_SIZE,
    validation_split=0.3,
    subset='training',
    label_mode='categorical',
    seed=STUDENT_ID,
    batch_size=batch_size,
    color_mode='grayscale'
)

validation_dataset_gray = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=IMG_SIZE,
    validation_split=0.3,
    subset='validation',
    label_mode='categorical',
    seed=STUDENT_ID,
    batch_size=batch_size,
    color_mode='grayscale'
)

# Split validation into validation and test
val_batches = tf.data.experimental.cardinality(validation_dataset_gray) // 3
test_dataset_gray = validation_dataset_gray.skip(val_batches)
validation_dataset_gray = validation_dataset_gray.take(val_batches)

# Optimize loading
train_dataset_gray = train_dataset_gray.cache().prefetch(buffer_size=AUTOTUNE)
validation_dataset_gray = validation_dataset_gray.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset_gray = test_dataset_gray.cache().prefetch(buffer_size=AUTOTUNE)

# We need to repeat the grayscale channel 3 times to match our model input shape
def expand_grayscale(images, labels):
    images = tf.repeat(images, 3, axis=-1)
    return images, labels

train_dataset_gray = train_dataset_gray.map(expand_grayscale)
validation_dataset_gray = validation_dataset_gray.map(expand_grayscale)
test_dataset_gray = test_dataset_gray.map(expand_grayscale)
# Out:
# Found 125912 files belonging to 18 classes.
# Using 88139 files for training.
# Found 125912 files belonging to 18 classes.
# Using 37773 files for validation.

# %%
# Let's see what a grayscale image looks like
plt.figure(figsize=(10, 5))
for images, labels in train_dataset_gray.take(1):
    for i in range(5):
        plt.subplot(1, 5, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        label_index = np.argmax(labels[i])
        plt.title(class_names[label_index])
        plt.axis("off")
plt.show()

# %%
# Build a CNN model for grayscale
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)))
model.add(data_augmentation_layers)
model.add(layers.Rescaling(1./255))
model.add(layers.Conv2D(16, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(layers.Conv2D(32, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D())
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(num_classes, activation='softmax'))

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history_gray = model.fit(
    train_dataset_gray,
    validation_data=validation_dataset_gray,
    epochs=100,
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 55s 19ms/step - accuracy: 0.1081 - loss: 2.7835 - val_accuracy: 0.2670 - val_loss: 2.2804
# Epoch 2/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.2521 - loss: 2.3415 - val_accuracy: 0.3286 - val_loss: 2.1017
# Epoch 3/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.2992 - loss: 2.1894 - val_accuracy: 0.3510 - val_loss: 2.0053
# Epoch 4/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.3302 - loss: 2.0795 - val_accuracy: 0.3818 - val_loss: 1.9077
# Epoch 5/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.3550 - loss: 1.9995 - val_accuracy: 0.3919 - val_loss: 1.8819
# Epoch 6/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.3750 - loss: 1.9382 - val_accuracy: 0.4101 - val_loss: 1.8228
# Epoch 7/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.3922 - loss: 1.8903 - val_accuracy: 0.4272 - val_loss: 1.7747
# Epoch 8/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.4026 - loss: 1.8464 - val_accuracy: 0.4275 - val_loss: 1.7899
# Epoch 9/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.4158 - loss: 1.8102 - val_accuracy: 0.4264 - val_loss: 1.7706
# Epoch 10/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.4224 - loss: 1.7864 - val_accuracy: 0.4316 - val_loss: 1.7526
# Epoch 11/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.4319 - loss: 1.7676 - val_accuracy: 0.4535 - val_loss: 1.6982
# Epoch 12/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.4352 - loss: 1.7440 - val_accuracy: 0.4420 - val_loss: 1.7289
# Epoch 13/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.4394 - loss: 1.7299 - val_accuracy: 0.4521 - val_loss: 1.6988
# Epoch 14/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.4487 - loss: 1.7036 - val_accuracy: 0.4462 - val_loss: 1.7169
# Epoch 15/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.4525 - loss: 1.6886 - val_accuracy: 0.4637 - val_loss: 1.6600
# Epoch 16/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.4581 - loss: 1.6757 - val_accuracy: 0.4586 - val_loss: 1.6716
# Epoch 17/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.4618 - loss: 1.6607 - val_accuracy: 0.4691 - val_loss: 1.6335
# Epoch 18/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.4665 - loss: 1.6383 - val_accuracy: 0.4761 - val_loss: 1.6157
# Epoch 19/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.4738 - loss: 1.6196 - val_accuracy: 0.4653 - val_loss: 1.6666
# Epoch 20/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.4726 - loss: 1.6260 - val_accuracy: 0.4740 - val_loss: 1.6242
# Epoch 21/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.4743 - loss: 1.6179 - val_accuracy: 0.4682 - val_loss: 1.6439
# Epoch 22/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 26s 10ms/step - accuracy: 0.4818 - loss: 1.5877 - val_accuracy: 0.4752 - val_loss: 1.6212
# Epoch 23/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 27s 10ms/step - accuracy: 0.4816 - loss: 1.5936 - val_accuracy: 0.4760 - val_loss: 1.6314

# %% [markdown]
# # Transfer Learning
#
# ## Following the Pokemon example, we'll use transfer learning with a pre-trained model

# %%
# VGG16 requires images of at least 32x32
# Let's use 224x224 which is more standard for VGG16
IMG_SIZE_TL = (224, 224)

# Reload datasets with new image size
train_dataset_tl = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=IMG_SIZE_TL,
    validation_split=0.3,
    subset='training',
    label_mode='categorical',
    seed=STUDENT_ID,
    batch_size=batch_size
)

validation_dataset_tl = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=IMG_SIZE_TL,
    validation_split=0.3,
    subset='validation',
    label_mode='categorical',
    seed=STUDENT_ID,
    batch_size=batch_size
)

# Split validation into validation and test
val_batches = tf.data.experimental.cardinality(validation_dataset_tl) // 3
test_dataset_tl = validation_dataset_tl.skip(val_batches)
validation_dataset_tl = validation_dataset_tl.take(val_batches)

# Optimize loading
# train_dataset_tl = train_dataset_tl.cache().prefetch(buffer_size=AUTOTUNE)
# validation_dataset_tl = validation_dataset_tl.cache().prefetch(buffer_size=AUTOTUNE)
# test_dataset_tl = test_dataset_tl.cache().prefetch(buffer_size=AUTOTUNE)

# Remove .cache() from all datasets
train_dataset_tl = train_dataset_tl.prefetch(buffer_size=AUTOTUNE)
validation_dataset_tl = validation_dataset_tl.prefetch(buffer_size=AUTOTUNE)
test_dataset_tl = test_dataset_tl.prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 125912 files belonging to 18 classes.
# Using 88139 files for training.
# Found 125912 files belonging to 18 classes.
# Using 37773 files for validation.

# %%
# Load VGG16 pre-trained on ImageNet (same as Pokemon example)
base_model = tf.keras.applications.VGG16(
    weights='imagenet',
    input_shape=(IMG_SIZE_TL[0], IMG_SIZE_TL[1], 3),
    include_top=False
)

# Freeze the base model
base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Define input layer
inputs = tf.keras.Input(shape=(IMG_SIZE_TL[0], IMG_SIZE_TL[1], 3))

# For data augmentation
data_augmentation_layers_tl = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
])
x = data_augmentation_layers_tl(inputs)

# Preprocess input for VGG16
x = tf.keras.applications.vgg16.preprocess_input(x)

# Pass through base model
x = base_model(x, training=False)

# Add classification head
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(num_classes)(x)  # No softmax, following Pokemon example

# Create model
model = tf.keras.Model(inputs, outputs)

# %%
# Using from_logits=True since we're not using softmax
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "functional_39"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_5        │ (None, 224, 224,  │          0 │ input_layer_6[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 224, 224)  │          0 │ sequential_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 224, 224)  │          0 │ sequential_5[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 224, 224)  │          0 │ sequential_5[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack (Stack)       │ (None, 224, 224,  │          0 │ get_item[0][0],   │
# │                     │ 3)                │            │ get_item_1[0][0], │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 224, 224,  │          0 │ stack[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 7, 7, 512) │ 14,714,688 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 18)        │      9,234 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,723,922 (56.17 MB)
#  Trainable params: 9,234 (36.07 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %%
history_tl = model.fit(
    train_dataset_tl,
    validation_data=validation_dataset_tl,
    epochs=100,
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 319s 114ms/step - accuracy: 0.3025 - loss: 2.6845 - val_accuracy: 0.5680 - val_loss: 1.4029
# Epoch 2/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.5062 - loss: 1.5984 - val_accuracy: 0.5808 - val_loss: 1.3625
# Epoch 3/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.5196 - loss: 1.5580 - val_accuracy: 0.5774 - val_loss: 1.3930
# Epoch 4/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.5202 - loss: 1.5593 - val_accuracy: 0.5702 - val_loss: 1.4229
# Epoch 5/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.5182 - loss: 1.5589 - val_accuracy: 0.5779 - val_loss: 1.3908
# Epoch 6/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 313s 113ms/step - accuracy: 0.5216 - loss: 1.5680 - val_accuracy: 0.5759 - val_loss: 1.4063
# Epoch 7/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.5217 - loss: 1.5618 - val_accuracy: 0.5746 - val_loss: 1.3985

# %% [markdown]
# # Transfer Learning with Dropout
# ## Continuing to follow the Pokemon example, we'll add dropout to the transfer learning model

# %%
# Define input layer
inputs = tf.keras.Input(shape=(IMG_SIZE_TL[0], IMG_SIZE_TL[1], 3))

# For data augmentation
x = data_augmentation_layers_tl(inputs)

# Preprocess input for VGG16
x = tf.keras.applications.vgg16.preprocess_input(x)

# Pass through base model
x = base_model(x, training=False)

# Add classification head with dropout
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(num_classes)(x)  # No softmax

# Create model
model = tf.keras.Model(inputs, outputs)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "functional_40"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_5        │ (None, 224, 224,  │          0 │ input_layer_8[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, 224, 224)  │          0 │ sequential_5[1][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_4          │ (None, 224, 224)  │          0 │ sequential_5[1][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_5          │ (None, 224, 224)  │          0 │ sequential_5[1][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack_1 (Stack)     │ (None, 224, 224,  │          0 │ get_item_3[0][0], │
# │                     │ 3)                │            │ get_item_4[0][0], │
# │                     │                   │            │ get_item_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 224, 224,  │          0 │ stack_1[0][0]     │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 7, 7, 512) │ 14,714,688 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ vgg16[1][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 18)        │      9,234 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,723,922 (56.17 MB)
#  Trainable params: 9,234 (36.07 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# %%
history_tl_dropout = model.fit(
    train_dataset_tl,
    validation_data=validation_dataset_tl,
    epochs=100,
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 314s 113ms/step - accuracy: 0.2619 - loss: 3.1352 - val_accuracy: 0.5322 - val_loss: 1.4924
# Epoch 2/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.4104 - loss: 1.9294 - val_accuracy: 0.5425 - val_loss: 1.4551
# Epoch 3/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.4144 - loss: 1.9218 - val_accuracy: 0.5482 - val_loss: 1.4416
# Epoch 4/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.4157 - loss: 1.9285 - val_accuracy: 0.5485 - val_loss: 1.4297
# Epoch 5/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.4187 - loss: 1.9185 - val_accuracy: 0.5351 - val_loss: 1.4792
# Epoch 6/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.4146 - loss: 1.9232 - val_accuracy: 0.5312 - val_loss: 1.4994
# Epoch 7/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.4123 - loss: 1.9282 - val_accuracy: 0.5245 - val_loss: 1.5009
# Epoch 8/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.4173 - loss: 1.9223 - val_accuracy: 0.5391 - val_loss: 1.4599
# Epoch 9/100
# 2755/2755 ━━━━━━━━━━━━━━━━━━━━ 312s 113ms/step - accuracy: 0.4164 - loss: 1.9203 - val_accuracy: 0.5437 - val_loss: 1.4596

# %%
IMG_SIZE_LARGE = (299, 299)
batch_size = 8  # or 4

train_dataset_large = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=IMG_SIZE_LARGE,
    validation_split=0.3,
    subset='training',
    label_mode='categorical',
    seed=STUDENT_ID,
    batch_size=batch_size
)

validation_dataset_large = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    shuffle=True,
    image_size=IMG_SIZE_LARGE,
    validation_split=0.3,
    subset='validation',
    label_mode='categorical',
    seed=STUDENT_ID,
    batch_size=batch_size
)

val_batches = tf.data.experimental.cardinality(validation_dataset_large) // 3
test_dataset_large = validation_dataset_large.skip(val_batches)
validation_dataset_large = validation_dataset_large.take(val_batches)

# Use prefetch only (no cache)
train_dataset_large = train_dataset_large.prefetch(buffer_size=AUTOTUNE)
validation_dataset_large = validation_dataset_large.prefetch(buffer_size=AUTOTUNE)
test_dataset_large = test_dataset_large.prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 125912 files belonging to 18 classes.
# Using 88139 files for training.
# Found 125912 files belonging to 18 classes.
# Using 37773 files for validation.

# %%
# Load VGG16 for larger images
base_model_large = tf.keras.applications.VGG16(
    weights='imagenet',
    input_shape=(IMG_SIZE_LARGE[0], IMG_SIZE_LARGE[1], 3),
    include_top=False
)
base_model_large.trainable = False

# %%
# Define input layer
inputs = tf.keras.Input(shape=(IMG_SIZE_LARGE[0], IMG_SIZE_LARGE[1], 3))

# For data augmentation
data_augmentation_layers_large = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
])
x = data_augmentation_layers_large(inputs)

# Preprocess input for VGG16
x = tf.keras.applications.vgg16.preprocess_input(x)

# Pass through base model
x = base_model_large(x, training=False)

# Add classification head
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(num_classes)(x)  # No softmax

# Create model
model = tf.keras.Model(inputs, outputs)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_42"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10      │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_6        │ (None, 299, 299,  │          0 │ input_layer_10[0… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_6          │ (None, 299, 299)  │          0 │ sequential_6[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_7          │ (None, 299, 299)  │          0 │ sequential_6[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_8          │ (None, 299, 299)  │          0 │ sequential_6[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack_2 (Stack)     │ (None, 299, 299,  │          0 │ get_item_6[0][0], │
# │                     │ 3)                │            │ get_item_7[0][0], │
# │                     │                   │            │ get_item_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 299, 299,  │          0 │ stack_2[0][0]     │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 9, 9, 512) │ 14,714,688 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 18)        │      9,234 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,723,922 (56.17 MB)
#  Trainable params: 9,234 (36.07 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=8,
    restore_best_weights=True
)

# %%
history_large = model.fit(
    train_dataset_large,
    validation_data=validation_dataset_large,
    epochs=100,
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 11018/11018 ━━━━━━━━━━━━━━━━━━━━ 563s 51ms/step - accuracy: 0.3869 - loss: 2.1227 - val_accuracy: 0.5618 - val_loss: 1.4762
# Epoch 2/100
# 10877/11018 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.5398 - loss: 1.5221
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-6a84a0eaa0a4> in <cell line: 0>()
# ----> 1 history_large = model.fit(
#       2     train_dataset_large,
#       3     validation_data=validation_dataset_large,
#       4     epochs=100,
#       5     callbacks=[callback]
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     217                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218             ):
# --> 219                 opt_outputs = multi_step_on_iterator(iterator)
#     220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1681     cancellation_context = cancellation.context()
#    1682     if cancellation_context is None:
# -> 1683       outputs = execute.execute(
#    1684           name.decode("utf-8"),
#    1685           num_outputs=num_outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluation
#
# ## Let's evaluate our best model on the test set

# %%
# Create a probability model for predictions
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])

# Evaluate on test dataset
test_loss, test_accuracy = model.evaluate(test_dataset_large)
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# 3148/3148 ━━━━━━━━━━━━━━━━━━━━ 143s 44ms/step - accuracy: 0.6000 - loss: 1.3548
# Test accuracy: 0.5980

# %% [markdown]
# # Confusion Matrix
# ## Let's create a confusion matrix to understand per-class performance

# %%
import matplotlib.pyplot as plt

# Get predictions
predictions = np.array([])
true_labels = np.array([])

for x, y in test_dataset_large:
    pred = model(x)
    pred = tf.nn.softmax(pred)
    pred_class = tf.argmax(pred, axis=1).numpy()
    true_class = tf.argmax(y, axis=1).numpy()

    predictions = np.concatenate([predictions, pred_class]) if predictions.size else pred_class
    true_labels = np.concatenate([true_labels, true_class]) if true_labels.size else true_class

# Create confusion matrix
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(true_labels, predictions)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=45, ha='right')
plt.yticks(tick_marks, class_names)

# Add text annotations to the confusion matrix
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, format(cm[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-88ad752dd4f0> in <cell line: 0>()
#       6
#       7 for x, y in test_dataset_large:
# ----> 8     pred = model(x)
#       9     pred = tf.nn.softmax(pred)
#      10     pred_class = tf.argmax(pred, axis=1).numpy()
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     906                         outputs = super().__call__(*args, **kwargs)
#     907                 else:
# --> 908                     outputs = super().__call__(*args, **kwargs)
#     909                 # Change the layout for the layer output if needed.
#     910                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py in call(self, inputs, training, mask)
#     180                 if mask is not None:
#     181                     backend.set_keras_mask(x, mask)
# --> 182         outputs = self._run_through_graph(
#     183             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184         )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/function.py in _run_through_graph(self, inputs, operation_fn, call_fn)
#     169                     outputs = call_fn(op, *args, **kwargs)
#     170                 else:
# --> 171                     outputs = op(*args, **kwargs)
#     172
#     173                 # Update tensor_dict.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py in call(*args, **kwargs)
#     635         ):
#     636             kwargs["training"] = training
# --> 637         return operation(*args, **kwargs)
#     638
#     639     return call
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     906                         outputs = super().__call__(*args, **kwargs)
#     907                 else:
# --> 908                     outputs = super().__call__(*args, **kwargs)
#     909                 # Change the layout for the layer output if needed.
#     910                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in call(self, inputs, training, mask)
#     211     def call(self, inputs, training=None, mask=None):
#     212         if self._functional:
# --> 213             return self._functional.call(inputs, training=training, mask=mask)
#     214
#     215         # Fallback: Just apply the layer sequence.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py in call(self, inputs, training, mask)
#     180                 if mask is not None:
#     181                     backend.set_keras_mask(x, mask)
# --> 182         outputs = self._run_through_graph(
#     183             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184         )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/function.py in _run_through_graph(self, inputs, operation_fn, call_fn)
#     169                     outputs = call_fn(op, *args, **kwargs)
#     170                 else:
# --> 171                     outputs = op(*args, **kwargs)
#     172
#     173                 # Update tensor_dict.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py in call(*args, **kwargs)
#     635         ):
#     636             kwargs["training"] = training
# --> 637         return operation(*args, **kwargs)
#     638
#     639     return call
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py in __call__(self, inputs, **kwargs)
#      47                     self._convert_input_args = True
#      48             return outputs
# ---> 49         return super().__call__(inputs, **kwargs)
#      50
#      51     @tracking.no_automatic_dependency_tracking
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     906                         outputs = super().__call__(*args, **kwargs)
#     907                 else:
# --> 908                     outputs = super().__call__(*args, **kwargs)
#     909                 # Change the layout for the layer output if needed.
#     910                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/image_preprocessing/base_image_preprocessing_layer.py in call(self, data, training)
#     130
#     131     def call(self, data, training=True):
# --> 132         transformation = self.get_random_transformation(data, training=training)
#     133         if isinstance(data, dict):
#     134             is_batched = self._is_batched(data["images"])
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/image_preprocessing/random_flip.py in get_random_transformation(self, data, training, seed)
#      83
#      84         flips = self.backend.numpy.less_equal(
# ---> 85             self.backend.random.uniform(shape=flips_shape, seed=seed), 0.5
#      86         )
#      87         return {"flips": flips, "input_shape": shape}
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/random.py in uniform(shape, minval, maxval, dtype, seed)
#      32     dtype = dtype or floatx()
#      33     seed = _cast_seed(draw_seed(seed))
# ---> 34     return tf.random.stateless_uniform(
#      35         shape=shape,
#      36         minval=tf.cast(minval, dtype),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/stateless_random_ops.py in stateless_random_uniform(shape, seed, minval, maxval, dtype, name, alg)
#     386       )
#     387     else:
# --> 388       minval = ops.convert_to_tensor(minval, dtype=dtype, name="min")
#     389       maxval = ops.convert_to_tensor(maxval, dtype=dtype, name="max")
#     390       if dtype.is_integer:
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     730   # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     731   preferred_dtype = preferred_dtype or dtype_hint
# --> 732   return tensor_conversion_registry.convert(
#     733       value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     734   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207   overload = getattr(value, "__tf_tensor__", None)
#     208   if overload is not None:
# --> 209     return overload(dtype, name)  #  pylint: disable=not-callable
#     210
#     211   for base_type, conversion_func in get(type(value)):
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py in __tf_tensor__(self, dtype, name)
#     616       self, dtype: Optional[dtypes.DType] = None, name: Optional[str] = None
#     617       ) -> tensor_lib.Tensor:
# --> 618     if not context.executing_eagerly():
#     619       graph = get_default_graph()
#     620       if not graph.building_function:
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in executing_eagerly()
#    2568
#    2569
# -> 2570 @tf_export("executing_eagerly", v1=[])
#    2571 def executing_eagerly():
#    2572   """Checks whether the current thread has eager execution enabled.
#
# KeyboardInterrupt:

# %% [markdown]
# # Testing on Custom Images
#
# ## Let's test our model on some custom images of gestures
# ## This part is specific to the project requirements

# %%
from PIL import Image

custom_image_paths = [
    # "IMG_6807.jpg",
    # "image.jpeg",
    "one-finger.jpg",
    "caolansbackofpalm.jpg",
    "caolans-three-fingers.jpg",
    "caolans-fist.jpg",
]

# %%
plt.figure(figsize=(15, 10))

for i, image_path in enumerate(custom_image_paths):
    # Load and resize image
    try:
        img = Image.open(image_path).resize((IMG_SIZE_LARGE[0], IMG_SIZE_LARGE[1]))
        img_array = np.array(img)
        img_array = np.expand_dims(img_array, 0)  # Add batch dimension

        # Make prediction
        predictions = probability_model.predict(img_array)
        predicted_class = np.argmax(predictions[0])
        confidence = predictions[0][predicted_class]

        # Display image and prediction
        plt.subplot(2, 2, i + 1)
        plt.imshow(img)
        plt.title(f"Predicted: {class_names[predicted_class]}\nConfidence: {confidence:.2f}")
        plt.axis("off")
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %% [markdown]
# # Summary of Results
#
# ## Let's create a summary table to compare all our models, following the assignment requirements

# %%
# Create a dictionary to store results
model_results = {
    "Model": [
        "Basic CNN",
        "CNN with Data Augmentation",
        "CNN with Augmentation & Dropout",
        "CNN with Grayscale Images",
        "Transfer Learning (VGG16, 224x224)",
        "Transfer Learning with Dropout",
        "Transfer Learning (VGG16, 299x299)"
    ],
    "Training Accuracy": [
        max(history.history['accuracy']),
        max(history_aug.history['accuracy']),
        max(history_dropout.history['accuracy']),
        max(history_gray.history['accuracy']),
        max(history_tl.history['accuracy']),
        max(history_tl_dropout.history['accuracy']),
        max(history_large.history['accuracy'])
    ],
    "Validation Accuracy": [
        max(history.history['val_accuracy']),
        max(history_aug.history['val_accuracy']),
        max(history_dropout.history['val_accuracy']),
        max(history_gray.history['val_accuracy']),
        max(history_tl.history['val_accuracy']),
        max(history_tl_dropout.history['val_accuracy']),
        max(history_large.history['val_accuracy'])
    ],
    "Test Accuracy": [
        "-", "-", "-", "-", "-", "-", test_accuracy
    ],
    "Training Time (epochs)": [
        len(history.history['accuracy']),
        len(history_aug.history['accuracy']),
        len(history_dropout.history['accuracy']),
        len(history_gray.history['accuracy']),
        len(history_tl.history['accuracy']),
        len(history_tl_dropout.history['accuracy']),
        len(history_large.history['accuracy'])
    ],
    "Parameters": [
        model.count_params(),
        model.count_params(),
        model.count_params(),
        model.count_params(),
        model.count_params(),
        model.count_params(),
        model.count_params()
    ]
}

# Create DataFrame and display
results_df = pd.DataFrame(model_results)
print(results_df)

# Save results to CSV for the paper
results_df.to_csv("model_comparison_results.csv", index=False)

# Save the Best Model

# Save the model for future use
# model.save("best_gesture_recognition_model")

# print("Training and evaluation complete!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-ad9e01043a99> in <cell line: 0>()
#      17         max(history_tl.history['accuracy']),
#      18         max(history_tl_dropout.history['accuracy']),
# ---> 19         max(history_large.history['accuracy'])
#      20     ],
#      21     "Validation Accuracy": [
#
# NameError: name 'history_large' is not defined
